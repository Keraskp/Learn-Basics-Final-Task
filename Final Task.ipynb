# %% [markdown]
# # Learn Basics Final Task :
# This Python Notebook is the final task from Learn Basics.
#
# **Done by Aditya Kiran Pal**
# || **Gmail :** adityakiran.cs@gmail.com
# || **Phone No. : 8118996525**
#
# **Problem Statement :** Given a csv or xlsx like [input](https://learnbasicsfun-my.sharepoint.com/:x:/g/personal/saran_learnbasics_fun/EWVde3y0mgFDqak-3f9sfwEBJDWEHCjEZ6h7j_HqLICvcw?e=gvGVVA), format the csv file according to this [output](https://learnbasicsfun-my.sharepoint.com/:x:/g/personal/saran_learnbasics_fun/EYzUTOhjve9PjTLEBmvJm80BkcubyfbD9ulscGNxgFMT9w?e=eyxsdb). Remove those tests whose parameters are empty.
#
# ### Dependencies :
# - openpyxl (dependency required to read excel files)
# - pandas

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Loading Data :

# %%
# Enter path of the xlsx file
file1_path = './input/Input_1.xlsx' 
file2_path = './input/Input_2.xlsx'

# %%
# Reading excel file using read_excel() method. sheet_name must be specified or method will return a
# dictionary containing all sheets in the excel file

df1 = pd.read_excel(file1_path, sheet_name='in')
df2 = pd.read_excel(file2_path, sheet_name='in')

# %%
#Alternatively csv file can be read using pandas
# file1_path = './input/Input_1.csv' 
# file2_path = './input/Input_2.csv'

# df1 = pd.read_csv(file_name1)
# df2 = pd.read_csv(file_name2)

# %%
df1.head() # prints first 5 rows of the DataFrame
# Out:
#       Name  id Chapter Tag Concept Test 1 - score  \
# 0  Darshan  34       C8S11                      4
# 1    Durga  35       C8S11                      3
# 2    Idhaz  36       C8S11                      5
# 3  Kishore  37       C8S11                      1
# 4     Mano  38       C8S11                      4
#
#   Concept Test 1 - time-taken (seconds) Concept Test 1 - answered  \
# 0                                   118                         4
# 1                                   886                         5
# 2                                   112                         5
# 3                                    29                         3
# 4                                   242                         5
#
#   Concept Test 1- correct Concept Test 1- wrong Concept Test 1- skipped  \
# 0                       4                     0                       1
# 1                       3                     2                       0
# ...

# %%
df2.head()
# Out:
#       Name  id Chapter Tag Concept Test 1 - score  \
# 0  Darshan  34       C8S10                      -
# 1    Durga  35       C8S10                      -
# 2    Idhaz  36       C8S10                      2
# 3  Kishore  37       C8S10                      -
# 4     Mano  38       C8S10                      2
#
#   Concept Test 1 - time-taken (seconds) Concept Test 1 - answered  \
# 0                                     -                         -
# 1                                     -                         -
# 2                                   125                         5
# 3                                     -                         -
# 4                                   136                         5
#
#   Concept Test 1- correct Concept Test 1- wrong Concept Test 1- skipped  \
# 0                       -                     -                       -
# 1                       -                     -                       -
# ...

# %% [markdown]
# ### Function to generate output DataFrame :

# %%
def Format(df): #DataFrame to be passed as arguement
    
    data_output = []
    
    # Output DataFrame Columns
    columns_output = ['Name','Username','Chapter Tag','Test_Name','score','time-taken (seconds)','answered','correct','wrong','skipped']
    
    n_names = df.shape[0]      # No of rows in input file
    n_columns = df.shape[1]    # No of columns in input file
    
    # Iterate through each row and append data in data_output
    
    for i in range(n_names):
        Name = df['Name'][i]
        Username = df['id'][i]
        ChapterTag = df['Chapter Tag'][i]
        
        j=3
        while j<n_columns:
            Data = [Name,Username,ChapterTag]
            if df.iloc[i][j]=='-':
                j+=6
                continue
            Data.append(df.columns[j].replace(' - score',''))
            Data.extend([df.iloc[i][j], df.iloc[i][j+1], df.iloc[i][j+2], df.iloc[i][j+3], df.iloc[i][j+4], df.iloc[i][j+5]])
            print(Data)
            data_output.append(Data)
            j+= 6
    
    # Creating output DataFrame
    df_output = pd.DataFrame(data_output,columns=columns_output)
    
    # Rearranging columns to match given file :
    df_output = df_output[['Name','Username','Chapter Tag','Test_Name','answered','correct','score','skipped','time-taken (seconds)','wrong']]
    
    return df_output

# %%
df_output1 = Format(df1)
# Out:
# ['Darshan', 34, 'C8S11', 'Concept Test 1', 4, 118, 4, 4, 0, 1]
# ['Darshan', 34, 'C8S11', 'Concept Test 2', 1, 320, 4, 1, 3, 1]
# ['Darshan', 34, 'C8S11', 'Concept Test 3', 4, 199, 5, 4, 1, 0]
# ['Darshan', 34, 'C8S11', 'Concept Test 4', 3, 161, 5, 3, 2, 0]
# ['Darshan', 34, 'C8S11', 'Topic Test 1', 5, 341, 10, 5, 5, 0]
# ['Darshan', 34, 'C8S11', 'Concept Test 5', 3, 122, 5, 3, 2, 0]
# ['Darshan', 34, 'C8S11', 'Topic Test 2', 6, 388, 10, 6, 4, 0]
# ['Darshan', 34, 'C8S11', 'Full Chapter Test 1', 6, 496, 10, 6, 4, 0]
# ['Darshan', 34, 'C8S11', 'Full Chapter Test 2', 6, 397, 10, 6, 4, 0]
# ['Durga', 35, 'C8S11', 'Concept Test 1', 3, 886, 5, 3, 2, 0]
# ['Durga', 35, 'C8S11', 'Concept Test 2', 3, 1176, 5, 3, 2, 0]
# ['Durga', 35, 'C8S11', 'Concept Test 3', 2, 732, 5, 2, 3, 0]
# ['Durga', 35, 'C8S11', 'Concept Test 4', 4, 312, 5, 4, 1, 0]
# ['Durga', 35, 'C8S11', 'Topic Test 1', 5, 788, 10, 5, 5, 0]
# ['Durga', 35, 'C8S11', 'Concept Test 5', 4, 525, 5, 4, 1, 0]
# ...

# %%
df_output1
# Out:
#         Name  Username Chapter Tag            Test_Name  answered  correct  \
# 0    Darshan        34       C8S11       Concept Test 1         4        4
# 1    Darshan        34       C8S11       Concept Test 2         4        1
# 2    Darshan        34       C8S11       Concept Test 3         5        4
# 3    Darshan        34       C8S11       Concept Test 4         5        3
# 4    Darshan        34       C8S11         Topic Test 1        10        5
# ..       ...       ...         ...                  ...       ...      ...
# 100  Vignesh        47       C8S11       Concept Test 4         5        2
# 101  Vignesh        47       C8S11         Topic Test 1        10        3
# 102  Vignesh        47       C8S11       Concept Test 5         5        4
# 103  Vignesh        47       C8S11         Topic Test 2         9        6
# 104  Vignesh        47       C8S11  Full Chapter Test 1        10        4
#
#      score  skipped  time-taken (seconds)  wrong
# ...

# %%
df_output2 = Format(df2)
# Out:
# ['Darshan', 34, 'C8S10', 'Concept Test 2', 3, 187, 4, 3, 1, 1]
# ['Darshan', 34, 'C8S10', 'Topic Test 1', 6, 365, 8, 6, 2, 2]
# ['Darshan', 34, 'C8S10', 'Concept Test 3', 3, 175, 3, 3, 0, 2]
# ['Darshan', 34, 'C8S10', 'Concept Test 4', 3, 91, 4, 3, 1, 1]
# ['Darshan', 34, 'C8S10', 'Concept Test 5', 3, 84, 3, 3, 0, 2]
# ['Darshan', 34, 'C8S10', 'Topic Test 2', 6, 234, 8, 6, 2, 2]
# ['Darshan', 34, 'C8S10', 'Full Chapter Test 1', 3, 74, 6, 3, 3, 4]
# ['Darshan', 34, 'C8S10', 'Full Chapter Test 2', 6, 270, 10, 6, 4, 0]
# ['Durga', 35, 'C8S10', 'Concept Test 4', 4, 665, 5, 4, 1, 0]
# ['Durga', 35, 'C8S10', 'Concept Test 5', 4, 360, 5, 4, 1, 0]
# ['Durga', 35, 'C8S10', 'Topic Test 2', 7, 691, 10, 7, 3, 0]
# ['Durga', 35, 'C8S10', 'Full Chapter Test 1', 5, 1674, 10, 5, 5, 0]
# ['Durga', 35, 'C8S10', 'Full Chapter Test 2', 6, 1066, 10, 6, 4, 0]
# ['Idhaz', 36, 'C8S10', 'Concept Test 1', 2, 125, 5, 2, 3, 0]
# ['Idhaz', 36, 'C8S10', 'Concept Test 2', 4, 79, 5, 4, 1, 0]
# ...

# %%
df_output2
# Out:
#        Name  Username Chapter Tag            Test_Name  answered  correct  \
# 0   Darshan        34       C8S10       Concept Test 2         4        3
# 1   Darshan        34       C8S10         Topic Test 1         8        6
# 2   Darshan        34       C8S10       Concept Test 3         3        3
# 3   Darshan        34       C8S10       Concept Test 4         4        3
# 4   Darshan        34       C8S10       Concept Test 5         3        3
# ..      ...       ...         ...                  ...       ...      ...
# 67   Thanis        46       C8S10       Concept Test 4         4        2
# 68   Thanis        46       C8S10       Concept Test 5         5        2
# 69   Thanis        46       C8S10         Topic Test 2        10        4
# 70   Thanis        46       C8S10  Full Chapter Test 1        10        3
# 71   Thanis        46       C8S10  Full Chapter Test 2        10        7
#
#     score  skipped  time-taken (seconds)  wrong
# ...

# %% [markdown]
# ### Generating Output CSV File :

# %%
df_output1.to_csv('./output/output1.csv', index=False,header=True)

# %%
df_output2.to_csv('./output/output1.csv', index=False,header=True)
